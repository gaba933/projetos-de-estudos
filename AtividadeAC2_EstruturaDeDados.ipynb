# %% [markdown]
# <a href="https://colab.research.google.com/github/gaba933/projetos-de-estudos/blob/main/AtividadeAC2_EstruturaDeDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Atividade - AC 2 - Estrutura de Dados**
#
# Prof. Rodrigo Luiz Gigante

# %% [markdown]
# ----
# | Nome                          |      RA             |
# |:-                             |:-------------------:|
# | Informe o nome aqui         | Informe o RA aqui |
# | Informe o nome aqui         | Informe o RA aqui |
# | Informe o nome aqui         | Informe o RA aqui |

# %% [markdown]
# ### Instruções
#
# 1. Altere apenas a região onde está escrito "**ESCREVA SEU CÓDIGO AQUI**".
#
# 1. Leia atentamente a descrição dos exercícios para garantir que você está executando o que foi pedido. Se o exercício informar o nome de classes, funções ou variáveis, você deve usar esses nomes exatamente como informado, incluindo letras minúsculas ou maiúsculas.
#
# 1. Antes de submeter o notebook, certifique-se que não há erros de código. Uma forma de se certificar disso é usar a opção **"Reiniciar Kernel e executar todas as células"** do Jupyter ou a opção **"Reiniciar e executar tudo"** do Google Colab.
#
# 1. Siga boas práticas de programação, pois isso **valerá nota**.
#     - dar nomes intuitivos para as variáveis
#     - dar nomes intuitivos para as funções
#     - comentar o código
#
# 1. Cuidado com plágio. Se for detectado plágio, a punição será  dada para  todos os envolvidos: todos do grupo que copiou e todos do grupo que forneceu a cópia.
#
# 1. Não é permitido que o grupo tenha pessoas de uma turma diferente da sua. Apenas uma pessoa do grupo deve submeter o trabalho. Você deve submeter apenas o arquivo .ipynb.

# %% [markdown]
# ---
# ## Exercício 1
#
# Escreva uma função chamada **compara** que receba como parâmetro uma pilha e uma fila. Ela deve retornar True caso as duas estruturas passadas como parâmetro sejam iguais e False caso contrário. Um pilha e uma fila são consideradas iguais tanto quando os elementos estão na mesma ordem ou em ordem contrária. Por exemplo, a pilha A=[0,1,2,3,4] é igual as filas B = [0,1,2,3,4] e C = [4,3,2,1,0].
#
# - Você deve garantir que ao final da função, a pilha e fila passadas como parâmetro estejam intactas, isto é, como os mesmos valores passados como entrada.

# %%
################# ESCREVA SEU CÓDIGO AQUI  ###############################
class Node:
    """
    Noh de uma fila dinamica
    """
    def __init__(self, data = None, next = None):
        self.data = data
        self.next = next

class Fila:
    """
    Fila dinamica
    """

    def __init__(self):
        self.front = None
        self.rear = None
        self.size = 0
        
    def enqueue(self, data):
        """
        Adiciona um elemento no final da fila
        """

        # cria um novo noh com o dado informado, mas que 
        # nao aponta para nenhum outro, ja que sera o ultimo da fila
        tempNode = Node(data)
            
        # se a fila esta vazia, o element rear
        # ira receber o novo noh.
        # Nesse caso,o elemento front devera apontar para 
        # o mesmo noh do elemento rear
        if self.rear is None:
            self.rear = tempNode
            self.front = self.rear
            
        else:
            
            # o noh rear sera substituido pelo novo noh e, por isso,
            # deve apontar para o novo noh
            self.rear.next = tempNode
            
            # o noh rear aponta para o novo noh
            self.rear = tempNode
        
        self.size += 1

    def dequeue(self):
        """
        Retorna e remove o elemento no inicio da fila
        """
        
        if self.size == 0:
            print("Fila vazia")
            return None
        
        # pega o dado do elemento front atual
        data = self.front.data
        
        # o novo elemento front sera o noh que o 
        # elemento front que esta sendo removido estava apontando antes
        self.front = self.front.next
        
        # caso o novo elemento front seja None (ou seja, a fila ficou vazia) 
        # o elemento rear tambem deve ser setado como none
        if self.front is None:
            self.rear = None
        
        # diminui a quantidade de elementos da fila
        self.size -= 1

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return data
    
    def getSize(self):
        """
        Retorna a quantidade de elementos da fila
        """
        
        return self.size

    def isEmpty(self):
        """
        Retorna True se a fila esta vazia
        """
        
        return self.front is None

    def getFront(self):
        """
        Retorna o primeiro elemento da lista sem remover
        """
        
        if self.front is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return self.front.data

    def clear(self):
        """
        Limpa a fila
        """
        
        while not self.isEmpty():
            data = self.dequeue()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da fila
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """

        # cria uma nova fila auxiliar
        auxfila = Fila()
        
        # retira os elementos da fila antiga e preenche a auxiliar
        for i in range( self.size ):
            auxfila.enqueue( self.dequeue() )
            
        # cria uma string com os elementos da fila auxiliar e
        # enquanto isso, preenche novamente a fila original
        strfila = '['
        for i in range( auxfila.size ):
            
            front = auxfila.dequeue()
            
            # preenche a fila original
            self.enqueue(front)
            
            # guarda o front em uma string
            strfila += ' ' + str(front)
            
        strfila += ' ]'
        
        return strfila

"""
fila que sera usada para auxiliar no processo
"""
class FilaAux:
    """
    Fila dinamica
    """

    def __init__(self):
        self.front = None
        self.rear = None
        self.size = 0
        
    def enqueue(self, data):
        """
        Adiciona um elemento no final da fila
        """

        # cria um novo noh com o dado informado, mas que 
        # nao aponta para nenhum outro, ja que sera o ultimo da fila
        tempNode = Node(data)
            
        # se a fila esta vazia, o element rear
        # ira receber o novo noh.
        # Nesse caso,o elemento front devera apontar para 
        # o mesmo noh do elemento rear
        if self.rear is None:
            self.rear = tempNode
            self.front = self.rear
            
        else:
            
            # o noh rear sera substituido pelo novo noh e, por isso,
            # deve apontar para o novo noh
            self.rear.next = tempNode
            
            # o noh rear aponta para o novo noh
            self.rear = tempNode
        
        self.size += 1

    def dequeue(self):
        """
        Retorna e remove o elemento no inicio da fila
        """
        
        if self.size == 0:
            print("Fila vazia")
            return None
        
        # pega o dado do elemento front atual
        data = self.front.data
        
        # o novo elemento front sera o noh que o 
        # elemento front que esta sendo removido estava apontando antes
        self.front = self.front.next
        
        # caso o novo elemento front seja None (ou seja, a fila ficou vazia) 
        # o elemento rear tambem deve ser setado como none
        if self.front is None:
            self.rear = None
        
        # diminui a quantidade de elementos da fila
        self.size -= 1

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return data
    
    def getSize(self):
        """
        Retorna a quantidade de elementos da fila
        """
        
        return self.size

    def isEmpty(self):
        """
        Retorna True se a fila esta vazia
        """
        
        return self.front is None

    def getFront(self):
        """
        Retorna o primeiro elemento da lista sem remover
        """
        
        if self.front is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return self.front.data

    def clear(self):
        """
        Limpa a fila
        """
        
        while not self.isEmpty():
            data = self.dequeue()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da fila
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """

        # cria uma nova fila auxiliar
        auxfila = Fila()
        
        # retira os elementos da fila antiga e preenche a auxiliar
        for i in range( self.size ):
            auxfila.enqueue( self.dequeue() )
            
        # cria uma string com os elementos da fila auxiliar e
        # enquanto isso, preenche novamente a fila original
        strfila = '['
        for i in range( auxfila.size ):
            
            front = auxfila.dequeue()
            
            # preenche a fila original
            self.enqueue(front)
            
            # guarda o front em uma string
            strfila += ' ' + str(front)
            
        strfila += ' ]'
        
        return strfila

"""
fila onde os dados da fila original salvos temporariamente
"""
class FilaSalva:
    """
    Fila dinamica
    """

    def __init__(self):
        self.front = None
        self.rear = None
        self.size = 0
        
    def enqueue(self, data):
        """
        Adiciona um elemento no final da fila
        """

        # cria um novo noh com o dado informado, mas que 
        # nao aponta para nenhum outro, ja que sera o ultimo da fila
        tempNode = Node(data)
            
        # se a fila esta vazia, o element rear
        # ira receber o novo noh.
        # Nesse caso,o elemento front devera apontar para 
        # o mesmo noh do elemento rear
        if self.rear is None:
            self.rear = tempNode
            self.front = self.rear
            
        else:
            
            # o noh rear sera substituido pelo novo noh e, por isso,
            # deve apontar para o novo noh
            self.rear.next = tempNode
            
            # o noh rear aponta para o novo noh
            self.rear = tempNode
        
        self.size += 1

    def dequeue(self):
        """
        Retorna e remove o elemento no inicio da fila
        """
        
        if self.size == 0:
            print("Fila vazia")
            return None
        
        # pega o dado do elemento front atual
        data = self.front.data
        
        # o novo elemento front sera o noh que o 
        # elemento front que esta sendo removido estava apontando antes
        self.front = self.front.next
        
        # caso o novo elemento front seja None (ou seja, a fila ficou vazia) 
        # o elemento rear tambem deve ser setado como none
        if self.front is None:
            self.rear = None
        
        # diminui a quantidade de elementos da fila
        self.size -= 1

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return data
    
    def getSize(self):
        """
        Retorna a quantidade de elementos da fila
        """
        
        return self.size

    def isEmpty(self):
        """
        Retorna True se a fila esta vazia
        """
        
        return self.front is None

    def getFront(self):
        """
        Retorna o primeiro elemento da lista sem remover
        """
        
        if self.front is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return self.front.data

    def clear(self):
        """
        Limpa a fila
        """
        
        while not self.isEmpty():
            data = self.dequeue()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da fila
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """

        # cria uma nova fila auxiliar
        auxfila = Fila()
        
        # retira os elementos da fila antiga e preenche a auxiliar
        for i in range( self.size ):
            auxfila.enqueue( self.dequeue() )
            
        # cria uma string com os elementos da fila auxiliar e
        # enquanto isso, preenche novamente a fila original
        strfila = '['
        for i in range( auxfila.size ):
            
            front = auxfila.dequeue()
            
            # preenche a fila original
            self.enqueue(front)
            
            # guarda o front em uma string
            strfila += ' ' + str(front)
            
        strfila += ' ]'
        
        return strfila

class Pilha:
    """
    Pilha dinamica
    """
    
    def __init__(self):
        self.head = None
        self.tamanho = 0

    def push(self, data):
        """
        Adiciona um elemento no topo da pilha
        """
        
        # se a pilha esta vazia, o element head
        # ira receber o novo noh. Mas, ele ira apontar
        # para None, pois nao existia nenhum noh antes
        if self.head is None:
            self.head = Node(data)
            
        else:
            
            # Cria um novo noh com o dado informado e que sera usado como novo topo. 
            # Esse novo noh ira apontar para o noh que era o topo antes
            temp = Node(data, self.head)
            
            # substitui o topo pelo novo noh
            self.head = temp
        
        self.tamanho += 1

    def pop(self):
        """
        Retorna e remove o elemento do topo da pilha
        """
        
        if self.head is None:
            print("Pilha vazia")
            return None
        
        data = self.head.data
        self.head = self.head.next
        
        self.tamanho -= 1

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o no inteiro
        return data
    
    def size(self):
        """
        Retorna a quantidade de elementos da pilha
        """
        
        return self.tamanho

    def isEmpty(self):
        """
        Retorna True se a pilha esta vazia
        """
        
        return self.head is None

    def getTop(self):
        """
        Retorna o topo da pilha sem remover
        """
        
        if self.head is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o no inteiro
        return self.head.data
            
    def clear(self):
        """
        Limpa a pilha
        """
        
        while not self.isEmpty():
            data = self.pop()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da pilha
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """
        # cria uma nova pilha auxiliar
        auxPilha = Pilha()
        
        # retira os elementos da pilha antiga e preenche a auxiliar
        # com isso, a auxiliar sera preenchida em ordem reversa
        while not self.isEmpty():
            data = self.pop()
            auxPilha.push( data )
            
            
            
        # cria uma string com os elementos da pilha auxiliar e
        # enquanto isso, preenche novamente a pilha original
        strPilha = '['
        while not auxPilha.isEmpty():
            
            top = auxPilha.pop()
            
            # preenche a pilha original
            self.push(top)
            
            # guarda o top em uma string
            strPilha += ' ' + str(top)
            
        strPilha += ' ]'
        
        return strPilha

"""
Pilha com a funcao de ajudar no processamento
"""
class PilhaAux:
    """
    Pilha dinamica
    """
    
    def __init__(self):
        self.head = None
        self.tamanho = 0

    def push(self, data):
        """
        Adiciona um elemento no topo da pilha
        """
        
        # se a pilha esta vazia, o element head
        # ira receber o novo noh. Mas, ele ira apontar
        # para None, pois nao existia nenhum noh antes
        if self.head is None:
            self.head = Node(data)
            
        else:
            
            # Cria um novo noh com o dado informado e que sera usado como novo topo. 
            # Esse novo noh ira apontar para o noh que era o topo antes
            temp = Node(data, self.head)
            
            # substitui o topo pelo novo noh
            self.head = temp
        
        self.tamanho += 1

    def pop(self):
        """
        Retorna e remove o elemento do topo da pilha
        """
        
        if self.head is None:
            print("Pilha vazia")
            return None
        
        data = self.head.data
        self.head = self.head.next
        
        self.tamanho -= 1

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o no inteiro
        return data
    
    def size(self):
        """
        Retorna a quantidade de elementos da pilha
        """
        
        return self.tamanho

    def isEmpty(self):
        """
        Retorna True se a pilha esta vazia
        """
        
        return self.head is None

    def getTop(self):
        """
        Retorna o topo da pilha sem remover
        """
        
        if self.head is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o no inteiro
        return self.head.data
            
    def clear(self):
        """
        Limpa a pilha
        """
        
        while not self.isEmpty():
            data = self.pop()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da pilha
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """
        # cria uma nova pilha auxiliar
        auxPilha = Pilha()
        
        # retira os elementos da pilha antiga e preenche a auxiliar
        # com isso, a auxiliar sera preenchida em ordem reversa
        while not self.isEmpty():
            data = self.pop()
            auxPilha.push( data )
            
            
            
        # cria uma string com os elementos da pilha auxiliar e
        # enquanto isso, preenche novamente a pilha original
        strPilha = '['
        while not auxPilha.isEmpty():
            
            top = auxPilha.pop()
            
            # preenche a pilha original
            self.push(top)
            
            # guarda o top em uma string
            strPilha += ' ' + str(top)
            
        strPilha += ' ]'
        
        return strPilha

"""
pilha onde sera salvo temporariamente os dados da pilha original
""" 
class PilhaSalva:
    """
    Pilha dinamica
    """
    
    def __init__(self):
        self.head = None
        self.tamanho = 0

    def push(self, data):
        """
        Adiciona um elemento no topo da pilha
        """
        
        # se a pilha esta vazia, o element head
        # ira receber o novo noh. Mas, ele ira apontar
        # para None, pois nao existia nenhum noh antes
        if self.head is None:
            self.head = Node(data)
            
        else:
            
            # Cria um novo noh com o dado informado e que sera usado como novo topo. 
            # Esse novo noh ira apontar para o noh que era o topo antes
            temp = Node(data, self.head)
            
            # substitui o topo pelo novo noh
            self.head = temp
        
        self.tamanho += 1

    def pop(self):
        """
        Retorna e remove o elemento do topo da pilha
        """
        
        if self.head is None:
            print("Pilha vazia")
            return None
        
        data = self.head.data
        self.head = self.head.next
        
        self.tamanho -= 1

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o no inteiro
        return data
    
    def size(self):
        """
        Retorna a quantidade de elementos da pilha
        """
        
        return self.tamanho

    def isEmpty(self):
        """
        Retorna True se a pilha esta vazia
        """
        
        return self.head is None

    def getTop(self):
        """
        Retorna o topo da pilha sem remover
        """
        
        if self.head is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o no inteiro
        return self.head.data
            
    def clear(self):
        """
        Limpa a pilha
        """
        
        while not self.isEmpty():
            data = self.pop()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da pilha
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """
        # cria uma nova pilha auxiliar
        auxPilha = Pilha()
        
        # retira os elementos da pilha antiga e preenche a auxiliar
        # com isso, a auxiliar sera preenchida em ordem reversa
        while not self.isEmpty():
            data = self.pop()
            auxPilha.push( data )
            
            
            
        # cria uma string com os elementos da pilha auxiliar e
        # enquanto isso, preenche novamente a pilha original
        strPilha = '['
        while not auxPilha.isEmpty():
            
            top = auxPilha.pop()
            
            # preenche a pilha original
            self.push(top)
            
            # guarda o top em uma string
            strPilha += ' ' + str(top)
            
        strPilha += ' ]'
        
        return strPilha

"""
a fila reversa funciona como uma pilha justamente para pegar os elementos na ordem inverca
"""
class FilaReversa:
    """
    Pilha dinamica
    """
    
    def __init__(self):
        self.head = None
        self.tamanho = 0

    def push(self, data):
        """
        Adiciona um elemento no topo da pilha
        """
        
        # se a pilha esta vazia, o element head
        # ira receber o novo noh. Mas, ele ira apontar
        # para None, pois nao existia nenhum noh antes
        if self.head is None:
            self.head = Node(data)
            
        else:
            
            # Cria um novo noh com o dado informado e que sera usado como novo topo. 
            # Esse novo noh ira apontar para o noh que era o topo antes
            temp = Node(data, self.head)
            
            # substitui o topo pelo novo noh
            self.head = temp
        
        self.tamanho += 1

    def pop(self):
        """
        Retorna e remove o elemento do topo da pilha
        """
        
        if self.head is None:
            print("Pilha vazia")
            return None
        
        data = self.head.data
        self.head = self.head.next
        
        self.tamanho -= 1

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o no inteiro
        return data
    
    def size(self):
        """
        Retorna a quantidade de elementos da pilha
        """
        
        return self.tamanho

    def isEmpty(self):
        """
        Retorna True se a pilha esta vazia
        """
        
        return self.head is None

    def getTop(self):
        """
        Retorna o topo da pilha sem remover
        """
        
        if self.head is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o no inteiro
        return self.head.data
            
    def clear(self):
        """
        Limpa a pilha
        """
        
        while not self.isEmpty():
            data = self.pop()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da pilha
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """
        # cria uma nova pilha auxiliar
        auxPilha = Pilha()
        
        # retira os elementos da pilha antiga e preenche a auxiliar
        # com isso, a auxiliar sera preenchida em ordem reversa
        while not self.isEmpty():
            data = self.pop()
            auxPilha.push( data )
            
            
            
        # cria uma string com os elementos da pilha auxiliar e
        # enquanto isso, preenche novamente a pilha original
        strPilha = '['
        while not auxPilha.isEmpty():
            
            top = auxPilha.pop()
            
            # preenche a pilha original
            self.push(top)
            
            # guarda o top em uma string
            strPilha += ' ' + str(top)
            
        strPilha += ' ]'
        
        return strPilha

"""
funcao principal onde o processo sera relizado
"""
def compara(fila, pilha):

    """
    inicializacao da das classes
    """
    pilhaAux = PilhaAux()
    pilhaSalva = PilhaSalva()

    filaAux = FilaAux()
    filaSalva = FilaSalva()
    filaReversa = FilaReversa()

    """
    verica se o tamanhos da fila e pilha
    se tiverem tamanhos diferentes ja sabemos
    que nao sao iguais
    """
    if pilha.size() != fila.getSize():
        print("tamanhos diferentes")
        return False

    """
    com base no tamanho da pilha seram manibulados os dados
    """
    for i in range( pilha.size() ):

        """
        os itens da fila sao armazenados um por vez
        no item e colocado nas outras filas
        """
        item2 = fila.dequeue()
        filaAux.enqueue(item2)
        filaReversa.push(item2)
        filaSalva.enqueue(item2)
        fila.enqueue(filaSalva.dequeue())
        
    for  i in range( pilha.size() ):
      
      """
      no aux1 sao salvos os elementos da pilha original
      """
      aux1 = pilha.pop()
      pilhaSalva.push(aux1)
      pilha.push(pilhaSalva.pop())
      """
      nos aux e aux3 sao salvos os elementos
      da  filaAux e filaReversa
      """
      aux2 = filaAux.dequeue()
      aux3 = filaReversa.pop()

      """
      com parando os elementos da pilha com filaAux e filaReversa
      observa-se que apesar do elementos de filaAux e filaReversa
      sao os mesmos e estao na mesma ordem, mas
      aux3 pega os elementos a partir do final
      """
      if aux1 != aux2 and aux1 != aux3:
        print("fila e pilha sao diferentes")
        return False      

    print("fila e pilha sao iguais")
    return True


if __name__ == "__main__":
    
    # testando a fila
    fila = Fila()
    pilha = Pilha()

    fila.enqueue(5)
    pilha.push(1)
    fila.enqueue(1)
    pilha.push(5)

    print(fila)
    print(pilha)

    compara(fila, pilha)

    print(fila)
    print(pilha)

    fila.clear()
    pilha.clear()

    print("----------")

    fila.enqueue(1)
    pilha.push(1)
    fila.enqueue(5)
    pilha.push(5)

    print(fila)
    print(pilha)

    compara(fila, pilha)

    print(fila)
    print(pilha)

    fila.clear()
    pilha.clear()

    print("----------")

    fila.enqueue(1)
    pilha.push(3)
    fila.enqueue(8)
    pilha.push(5)

    print(fila)
    print(pilha)

    compara(fila, pilha)

    print(fila)
    print(pilha)
    




##########################################################################

# %% [markdown]
# ---
# ## Exercício 2
#
# Escreva um programa cliente que utilize o tipo abstrato de dados Pilha para simular uma sessão com um caixa de banco. Contrariamente à maioria dos bancos,este decidiu que o último cliente a chegar será sempre o primeiro a ser obtido.
#
# Crie classes que representem informações sobre um cliente de um banco e uma transação. Para cada cliente você precisa armazenar um nome, saldo na conta corrente e uma referência à transação. Para cada transação, você precisa armazenar o tipo de transação (depósito ou retirada) e o valor da transação.
#
# Após cada cinco clientes serem processados, exiba o tamanho da pilha e o nome do próximo cliente a ser atendido.

# %%
# Criação das classes
class Cliente:
  def __init__(self,nome,saldo,conta):
    self.nome = nome
    self.saldo = saldo
    self.conta = conta

class Conta:
  def __init__(self,tipo,valor):
    self.tipo = tipo
    self.valor = valor

class Pilha:
  def __init__(self):
    # Inicializa a pilha com uma lista vazia:
    self.items= []

  def empty(self):
    # Identifica se a pilha estiver vazia:
    return len(self.items) == 0
  
  def stack(self,item):
    # Acrescenta um elemento no topo da pilha:
    self.items.append(item)

  def unstack(self):
    # Remove um elemento no topo da pilha:
    if self.empty():
      return None
    return self.items.pop()

  def size(self):
    # Retorna o número de elementos na pilha:
    return len(self.items)

# Implementação da pilha:
pilha = Pilha()
clientes_processados = 0

print("|---| Simulação de Caixa de Banco |---|")

lista_clientes = [
  # Exemplo de lista de clientes:
  Cliente("Scott Richards",100.0,Conta("depósito",500.0)),
  Cliente("Riley Gordon",5000.0,Conta("retirada", 1000.0)),
  Cliente("Ryan Leach",200.0,Conta("retirada", 50.0)),
  Cliente("Amari Nicholson",3000.0,Conta("depósito", 2000.0)),
  Cliente("Marcel Odom",1500.0,Conta("retirada",300.0)),
  Cliente("Isabella Bailey",400.0,Conta("depósito",100.0)),
  Cliente("Nicole Fox",1000.0,Conta("retirada",2000.0)),
  Cliente("Raylee Green",2500.0,Conta("depósito",1500.0)),
  Cliente("Chris Powell",800.0,Conta("retirada",100.0)),
  Cliente("Brett Ellison",500.0,Conta("depósito",300.0))
]
    
print("\nExecutando lista de clientes...")

# Imprime os dados dos clientes:
for i, cliente in enumerate(lista_clientes, start=1):
  pilha.stack(cliente)
  clientes_processados += 1

  if clientes_processados % 5 == 0:
    print("\nTamanho da pilha: ", pilha.size())
    if not pilha.empty():
      proximo_cliente = pilha.unstack()
      print("Próximo cliente a ser atendido: ", proximo_cliente.nome)
      pilha.stack(proximo_cliente)
      # Mantém o contador para o próximo ciclo:
      clientes_processados -= 1

# %% [markdown]
# ---
# ## Exercício 3
#
# Escreva um programa que simule a operação de um aeroporto movimentado que possui apenas duas pistas para controlar pouso e decolagem. Você deve supor que cada pouso ou decolagem leve 15 minutos para ser completamente realizado. Uma solicitação de pista é efetuada a cada intervalo de 5 minutos, e a probabilidade de uma solicitação de um pouso é a mesma de uma decolagem. A prioridade é dada às aeronaves que solicitam pouso. Se uma solicitação não puder ser atendida, ela é acrescentada à fila de pouso ou decolagem.
#
# Seu programa deve simular 120 minutos de atividade do aeroporto. Cada solicitação de liberação de pista deve ter o controle da hora do pedido e ser acrescentada à fila apropriada. A saída de seu programa deve incluir o conteúdo final da fila, o número de pousos e decolagens completados e o número médio de minutos gastos em cada fila.

# %%
################# ESCREVA SEU CÓDIGO AQUI  ###############################
class Node:
    
    def __init__(self, data, next=None):
        
        self.data = data
        self.next = next
        

class Pouso:
    """
    Fila dinamica
    """

    def __init__(self, data  = None):
        self.front = None
        self.rear = None
        self.size = 0
        
        # se na criacao da fila, um dado ja for passado
        # usa a funcao enqueue para adicionar esse dado
        if data is not None:
            self.enqueue(data)

    def enqueue(self, data):
        """
        Adiciona um elemento no final da fila
        """

        # cria um novo noh com o dado informado, mas que 
        # nao aponta para nenhum outro, ja que sera o ultimo da fila
        tempNode = Node(data)
            
        # se a fila esta vazia, o element rear
        # ira receber o novo noh.
        # Nesse caso,o elemento front devera apontar para 
        # o mesmo noh do elemento rear
        if self.rear is None:
            self.rear = tempNode
            self.front = self.rear
            
        else:
            
            # o noh rear sera substituido pelo novo noh e, por isso,
            # deve apontar para o novo noh
            self.rear.next = tempNode
            
            # o noh rear aponta para o novo noh
            self.rear = tempNode
        
        self.size += 1

    def dequeue(self):
        """
        Retorna e remove o elemento no inicio da fila
        """
        
        if self.size == 0:
            print("Fila vazia")
            return None
        
        # pega o dado do elemento front atual
        data = self.front.data
        
        # o novo elemento front sera o noh que o 
        # elemento front que esta sendo removido estava apontando antes
        self.front = self.front.next
        
        # caso o novo elemento front seja None (ou seja, a fila ficou vazia) 
        # o elemento rear tambem deve ser setado como none
        if self.front is None:
            self.rear = None
        
        # diminui a quantidade de elementos da fila
        self.size -= 1

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return data
    
    def getSize(self):
        """
        Retorna a quantidade de elementos da fila
        """
        
        return self.size

    def isEmpty(self):
        """
        Retorna True se a fila esta vazia
        """
        
        return self.front is None

    def getFront(self):
        """
        Retorna o primeiro elemento da lista sem remover
        """
        
        if self.front is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return self.front.data

    def clear(self):
        """
        Limpa a fila
        """
        
        while not self.isEmpty():
            data = self.dequeue()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da fila
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """

        # cria uma nova fila auxiliar
        auxfila = Pouso()
        
        # retira os elementos da fila antiga e preenche a auxiliar
        for i in range( self.size ):
            auxfila.enqueue( self.dequeue() )
            
        # cria uma string com os elementos da fila auxiliar e
        # enquanto isso, preenche novamente a fila original
        strfila = '['
        for i in range( auxfila.size ):
            
            front = auxfila.dequeue()
            
            # preenche a fila original
            self.enqueue(front)
            
            # guarda o front em uma string
            strfila += ' ' + str(front)
            
        strfila += ' ]'
        
        return strfila
        
class Decolar:
  """
  Fila dinamica
  """

  def __init__(self, data  = None):
      self.front = None
      self.rear = None
      self.size = 0
      
      # se na criacao da fila, um dado ja for passado
      # usa a funcao enqueue para adicionar esse dado
      if data is not None:
          self.enqueue(data)

  def enqueue(self, data):
      """
      Adiciona um elemento no final da fila
      """

      # cria um novo noh com o dado informado, mas que 
      # nao aponta para nenhum outro, ja que sera o ultimo da fila
      tempNode = Node(data)
          
      # se a fila esta vazia, o element rear
      # ira receber o novo noh.
      # Nesse caso,o elemento front devera apontar para 
      # o mesmo noh do elemento rear
      if self.rear is None:
          self.rear = tempNode
          self.front = self.rear
          
      else:
          
          # o noh rear sera substituido pelo novo noh e, por isso,
          # deve apontar para o novo noh
          self.rear.next = tempNode
          
          # o noh rear aponta para o novo noh
          self.rear = tempNode
      
      self.size += 1

  def dequeue(self):
      """
      Retorna e remove o elemento no inicio da fila
      """
      
      if self.size == 0:
          print("Fila vazia")
          return None
      
      # pega o dado do elemento front atual
      data = self.front.data
      
      # o novo elemento front sera o noh que o 
      # elemento front que esta sendo removido estava apontando antes
      self.front = self.front.next
      
      # caso o novo elemento front seja None (ou seja, a fila ficou vazia) 
      # o elemento rear tambem deve ser setado como none
      if self.front is None:
          self.rear = None
      
      # diminui a quantidade de elementos da fila
      self.size -= 1

      # iremos retornar apenas o dado do noh, mas
      # dependendo da necessidade, poderia ser
      # retornado o noh inteiro
      return data
  
  def getSize(self):
      """
      Retorna a quantidade de elementos da fila
      """
      
      return self.size

  def isEmpty(self):
      """
      Retorna True se a fila esta vazia
      """
      
      return self.front is None

  def getFront(self):
      """
      Retorna o primeiro elemento da lista sem remover
      """
      
      if self.front is None:
          print("Pilha vazia")
          return None

      # iremos retornar apenas o dado do noh, mas
      # dependendo da necessidade, poderia ser
      # retornado o noh inteiro
      return self.front.data

  def clear(self):
      """
      Limpa a fila
      """
      
      while not self.isEmpty():
          data = self.dequeue()
          
  def __str__(self):
      """
      Retorna uma string com as informacoes da fila
      quando o objeto e chamado dentro de um print() 
      ou dentro de um str(). 
      """

      # cria uma nova fila auxiliar
      auxfila = Decolar()
      
      # retira os elementos da fila antiga e preenche a auxiliar
      for i in range( self.size ):
          auxfila.enqueue( self.dequeue() )
          
      # cria uma string com os elementos da fila auxiliar e
      # enquanto isso, preenche novamente a fila original
      strfila = '['
      for i in range( auxfila.size ):
          
          front = auxfila.dequeue()
          
          # preenche a fila original
          self.enqueue(front)
          
          # guarda o front em uma string
          strfila += ' ' + str(front)
          
      strfila += ' ]'
      
      return strfila

import random

class Aeroporto:
    def __init__(self):

      self.pista_pouso = Pouso()
      self.pousos_completados = 0
      self.tempo_pouso = 0
      self.tempo_total_pouso = 0

      self.pista_decolagem = Decolar()
      self.decolagens_completadas = 0
      self.tempo_decolagem = 0
      self.tempo_total_decolagem = 0

    def solicitar_pista(self, tipo):
      if tipo == "decolagem":
        self.pista_decolagem.enqueue(tipo)

      elif tipo == "pouso":
        self.pista_pouso.enqueue(tipo)

    def solicitacoes(self):
      for tempo in range(120):

        if tempo % 5 == 0:
          if random.random() < 0.5:
            self.solicitar_pista("pouso")
          else:
            self.solicitar_pista("decolagem")
        
        if self.pista_pouso:
          self.tempo_pouso += 1
          self.tempo_total_pouso += 1
          if self.tempo_pouso >= 15:
            self.pista_pouso.dequeue()
            self.pousos_completados += 1
            self.tempo_pouso = 0
            self.tempo_total_pouso += 1

        if self.pista_decolagem:
          self.tempo_decolagem += 1
          self.tempo_total_decolagem += 1
          if self.tempo_decolagem >= 15:
            self.pista_decolagem.dequeue()
            self.decolagens_completadas += 1
            self.tempo_decolagem = 0
            self.tempo_total_decolagem += 1

      media_pouso = 0
      media_decolagem = 0

      if aeroporto.pousos_completados > 0:
          media_pouso = aeroporto.tempo_total_pouso / aeroporto.pousos_completados

      if aeroporto.decolagens_completadas > 0:
          media_decolagem = aeroporto.tempo_total_decolagem / aeroporto.decolagens_completadas    
        
      """
      saida
      """
      print("Conteúdo final da fila de pouso: ", self.pista_pouso)
      print("Conteúdo final da fila de decolagem: ", self.pista_decolagem)
      print("Numero total de pousos: ", self.pousos_completados)
      print("Numero total de decolagens: ", self.decolagens_completadas)
      print("Média de minutos gastos em pousos:", media_pouso)
      print("Média de minutos gastos em decolagens:", media_decolagem)    
      
aeroporto = Aeroporto()
aeroporto.solicitacoes()




##########################################################################

# %% [markdown]
# ---
# ## Exercício 4
#
# Implemente a busca em largura para uma árvore binária.

# %%
################# ESCREVA SEU CÓDIGO AQUI  ###############################
class Node:
    def __init__(self, data, next=None):
        self.data = data
        self.next = next


class Deque:
    """
    Deque (fila dupla) dinâmico
    """
    
    def __init__(self):
        
        self.front = None
        self.rear = None
        self.size = 0
            
    def isEmpty(self):
        
        if self.size == 0:
            return True
        else:
            return False
        
    def enqueueRear(self,valor):
        """
        Insere um elemento no final da fila
        """
        
        noh = Node( valor )
        
        if self.size==0:
            self.front = noh
            self.rear = noh
        
        else:
            self.rear.next = noh
            self.rear = noh
         
        # aumenta a qtd. de elementos da fila
        self.size += 1 
        
    def enqueueFront(self,valor):
        """
        Insere um elemento no inicio da fila
        """
        
        # cria um novo nó
        noh = Node(valor)
        
        if self.isEmpty():
            self.front = noh
            self.rear = noh
            
        else:
            
            noh.next = self.front
            
            self.front = noh

        # aumenta a qtd. de elementos da fila            
        self.size += 1
            
        
    def dequeueFront(self):
        """
        Elimina o primeiro elemento
        """
        
        if self.isEmpty():
            print('Erro. Underflow')
            return None
        else:
            
            nohAExcluir = self.front
            
            # retorna o valor
            valor = nohAExcluir.data
            
            # atualiza quem está na frente
            self.front = nohAExcluir.next
            
            # diminui o numero de elementos
            self.size -= 1
            
            # deleta o noh da memoria
            del nohAExcluir
            
            return valor
        
    def dequeueRear(self):
        """
        Elimina o ultimo elemento
        """
        
        if self.isEmpty():
            print('\nErro. Underflow')
            return None
            
        nohAExcluir = self.rear
        
        # retorna o valor
        valor = nohAExcluir.data
        
        # se o deque tiver tamanho 1, ao excluir o noh, ele ficara vazio
        if self.size==1:
            self.front = None
            self.rear = None
        else:
            # atualiza quem esta atras. Precisa tambem atualizar o next do no que sera o novo rear.
            # o unico jeito de achar o noh que sera o novo rear, eh percorrendo toda a fila
            nohAux = self.front
            novoRear = None 
            
            # Percorre a fila ate achar o elemento anterior ao rear. 
            # O laco para quando achar o rear, isto eh, um next igual ao None.
            while nohAux.next is not None:
                novoRear = nohAux
                nohAux = nohAux.next
                
            # troca o rear
            self.rear = novoRear
            
        # diminui o numero de elementos
        self.size -= 1
    
        # deleta o noh da memoria            
        del nohAExcluir
        
        return valor

    def getFront(self):
        """
        Retorna o primeiro elemento da lista sem remover
        """
        
        if self.front is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return self.front.data

    def getRear(self):
        """
        Retorna o ultimo elemento da lista sem remover
        """
        
        if self.rear is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return self.rear.data
        
    def getSize(self):
        """
        Retorna o tamanho da lista
        """
        
        return self.size
    
    def clear(self):
        """
        Apaga o deque
        """

        while not self.isEmpty():
            self.dequeueFront()
            
    
    def __str__(self):
          
        # fila auxiliar para imprimir a fila original
        dequeAux = Deque()
        
        # string que ira guardar os valores
        info = '[ '
        
        while not self.isEmpty():
            
            valor = self.dequeueFront()
            
            # insere na fila auxiliar
            dequeAux.enqueueRear( valor )
            
            info = info + ' ' + str(valor)
        
        info = info + ' ]'
        
        # laço para recuperar a fila 
        while not dequeAux.isEmpty():
            
            valor = dequeAux.dequeueFront()
            self.enqueueRear(valor)
            
        return info

class Resultado:
    """
    Fila dinamica
    """

    def __init__(self, data  = None):
        self.front = None
        self.rear = None
        self.size = 0
        
        # se na criacao da fila, um dado ja for passado
        # usa a funcao enqueue para adicionar esse dado
        if data is not None:
            self.enqueue(data)

    def enqueue(self, data):
        """
        Adiciona um elemento no final da fila
        """

        # cria um novo noh com o dado informado, mas que 
        # nao aponta para nenhum outro, ja que sera o ultimo da fila
        tempNode = Node(data)
            
        # se a fila esta vazia, o element rear
        # ira receber o novo noh.
        # Nesse caso,o elemento front devera apontar para 
        # o mesmo noh do elemento rear
        if self.rear is None:
            self.rear = tempNode
            self.front = self.rear
            
        else:
            
            # o noh rear sera substituido pelo novo noh e, por isso,
            # deve apontar para o novo noh
            self.rear.next = tempNode
            
            # o noh rear aponta para o novo noh
            self.rear = tempNode
        
        self.size += 1

    def dequeue(self):
        """
        Retorna e remove o elemento no inicio da fila
        """
        
        if self.size == 0:
            print("Fila vazia")
            return None
        
        # pega o dado do elemento front atual
        data = self.front.data
        
        # o novo elemento front sera o noh que o 
        # elemento front que esta sendo removido estava apontando antes
        self.front = self.front.next
        
        # caso o novo elemento front seja None (ou seja, a fila ficou vazia) 
        # o elemento rear tambem deve ser setado como none
        if self.front is None:
            self.rear = None
        
        # diminui a quantidade de elementos da fila
        self.size -= 1

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return data
    
    def getSize(self):
        """
        Retorna a quantidade de elementos da fila
        """
        
        return self.size

    def isEmpty(self):
        """
        Retorna True se a fila esta vazia
        """
        
        return self.front is None

    def getFront(self):
        """
        Retorna o primeiro elemento da lista sem remover
        """
        
        if self.front is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return self.front.data

    def clear(self):
        """
        Limpa a fila
        """
        
        while not self.isEmpty():
            data = self.dequeue()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da fila
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """

        # cria uma nova fila auxiliar
        auxfila = Resultado()
        
        # retira os elementos da fila antiga e preenche a auxiliar
        for i in range( self.size ):
            auxfila.enqueue( self.dequeue() )
            
        # cria uma string com os elementos da fila auxiliar e
        # enquanto isso, preenche novamente a fila original
        strfila = '['
        for i in range( auxfila.size ):
            
            front = auxfila.dequeue()
            
            # preenche a fila original
            self.enqueue(front)
            
            # guarda o front em uma string
            strfila += ' ' + str(front)
            
        strfila += ' ]'
        
        return strfila

class Level:
    """
    Fila dinamica
    """

    def __init__(self, data  = None):
        self.front = None
        self.rear = None
        self.size = 0
        
        # se na criacao da fila, um dado ja for passado
        # usa a funcao enqueue para adicionar esse dado
        if data is not None:
            self.enqueue(data)

    def enqueue(self, data):
        """
        Adiciona um elemento no final da fila
        """

        # cria um novo noh com o dado informado, mas que 
        # nao aponta para nenhum outro, ja que sera o ultimo da fila
        tempNode = Node(data)
            
        # se a fila esta vazia, o element rear
        # ira receber o novo noh.
        # Nesse caso,o elemento front devera apontar para 
        # o mesmo noh do elemento rear
        if self.rear is None:
            self.rear = tempNode
            self.front = self.rear
            
        else:
            
            # o noh rear sera substituido pelo novo noh e, por isso,
            # deve apontar para o novo noh
            self.rear.next = tempNode
            
            # o noh rear aponta para o novo noh
            self.rear = tempNode
        
        self.size += 1

    def dequeue(self):
        """
        Retorna e remove o elemento no inicio da fila
        """
        
        if self.size == 0:
            print("Fila vazia")
            return None
        
        # pega o dado do elemento front atual
        data = self.front.data
        
        # o novo elemento front sera o noh que o 
        # elemento front que esta sendo removido estava apontando antes
        self.front = self.front.next
        
        # caso o novo elemento front seja None (ou seja, a fila ficou vazia) 
        # o elemento rear tambem deve ser setado como none
        if self.front is None:
            self.rear = None
        
        # diminui a quantidade de elementos da fila
        self.size -= 1

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return data
    
    def getSize(self):
        """
        Retorna a quantidade de elementos da fila
        """
        
        return self.size

    def isEmpty(self):
        """
        Retorna True se a fila esta vazia
        """
        
        return self.front is None

    def getFront(self):
        """
        Retorna o primeiro elemento da lista sem remover
        """
        
        if self.front is None:
            print("Pilha vazia")
            return None

        # iremos retornar apenas o dado do noh, mas
        # dependendo da necessidade, poderia ser
        # retornado o noh inteiro
        return self.front.data

    def clear(self):
        """
        Limpa a fila
        """
        
        while not self.isEmpty():
            data = self.dequeue()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da fila
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """

        # cria uma nova fila auxiliar
        auxfila = Level()
        
        # retira os elementos da fila antiga e preenche a auxiliar
        for i in range( self.size ):
            auxfila.enqueue( self.dequeue() )
            
        # cria uma string com os elementos da fila auxiliar e
        # enquanto isso, preenche novamente a fila original
        strfila = '['
        for i in range( auxfila.size ):
            
            front = auxfila.dequeue()
            
            # preenche a fila original
            self.enqueue(front)
            
            # guarda o front em uma string
            strfila += ' ' + str(front)
            
        strfila += ' ]'
        
        return strfila

class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None


def primeira_busca(root):
    if not root:
        return []

    resultado = Resultado()
    deque = Deque()
    deque.enqueueRear(root)

    while not deque.isEmpty():
        level = Level()
        levelsize = deque.getSize()

        for _ in range(levelsize):
            node = deque.dequeueFront()
            level.enqueue(node.val)

            if node.left:
                deque.enqueueRear(node.left)

            if node.right:
                deque.enqueueRear(node.right)

        resultado.enqueue(level)

    return resultado

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(7)
root.left.right = TreeNode(8)
root.right.right = TreeNode(9)

result = primeira_busca(root)
print(result)





##########################################################################

# %% [markdown]
# ---
# ## Exercício 5
#
# Implemente uma estrutura de dados que seja ao mesmo tempo uma pilha e fila dinâmica usando um deque dinâmico. Você deve implementar todos os métodos de uma fila e de um pilha dinâmica nessa estrutura aproveitando tudo o que for possível do deque.

# %%
################# ESCREVA SEU CÓDIGO AQUI  ###############################
class Node:
    """
    Noh de uma fila dinamica
    """
    def __init__(self, data = None, next = None, prev=None):
        self.data = data
        self.next = next
        """
        e adicionado o elemento prev q aponta pro elemento anterior
        """
        self.prev = prev

class FilaEspecial:
    """
    Fila dinamica
    """

    def __init__(self, data  = None):
        self.topo = None
        self.base = None
        self.size = 0
        
        # se na criacao da fila, um dado ja for passado
        # usa a funcao enqueue para adicionar esse dado
        if data is not None:
            self.enqueue(data)

    def enqueue(self, data):
        """
        Adiciona um elemento segundo fila
        """

        temp = Node(data)

        if self.isEmpty():
          self.topo = temp
          self.base = self.topo

        else:
          aux = self.topo.data
          self.topo.next = temp
          self.topo = temp
          self.topo.prev = aux

        self.size += 1

    def push(self, data):
        """
        Adiciona um elemento segundo pilha
        """

        temp = Node(data)
        if self.isEmpty():
            self.topo = temp
        
        else:
            aux = self.topo.data
            self.topo.next = temp
            self.topo = temp
            self.topo.prev = aux

        self.size += 1

    def dequeue(self):
        """
        Retorna e remove o elemento do inicio como uma fila
        """
        
        if self.size == 0:
            print("Fila vazia")
            return None
        
        # pega o dado do elemento base atual
        data = self.base.data
        
        """
        o novo elemento base sera o noh que o 
        elemento base que esta sendo removido estava apontando antes
        """
        self.base = self.base.next

        """
        caso o novo elemento base seja None (ou seja, a fila ficou vazia) 
        o elemento topo tambem deve ser setado como none
        """
        if self.base is None:
            self.topo = None
        
        # diminui a quantidade de elementos da fila
        self.size -= 1

        """
        iremos retornar apenas o dado do noh, mas
        dependendo da necessidade, poderia ser
        retornado o noh inteiro
        """
        return data

    def pop(self):
        """
        Retorna e remove o elemento do final como uma pilha
        """

        if self.topo is None:
          print("vazio")
          return None
        
        data = self.topo.data
        self.topo = self.topo.prev

        self.size -= 1

        return data
    
    def getSize(self):
        """
        Retorna a quantidade de elementos da fila
        """
        
        return self.size

    def isEmpty(self):
        """
        Retorna True se a fila esta vazia
        """
        if self.size == 0:
            return True

        else:
            return False

    def getBase(self):
        """
        Retorna o primeiro elemento da lista sem remover igual uma fila
        """
        
        if self.base is None:
            print("Pilha vazia")
            return None

        """
        iremos retornar apenas o dado do noh, mas
        dependendo da necessidade, poderia ser
        retornado o noh inteiro
        """
        return self.base.data

    def getTopo(self):
        """
        Retorna o ultimo elemento da lista sem remover  igual uma pilha
        """

        if self.topo is None:
            print("vazio")
            return None
        
        return self.topo.data

    def clear(self):
        """
        Limpa a fila
        """
        
        while not self.isEmpty():
            data = self.dequeue()
            
    def __str__(self):
        """
        Retorna uma string com as informacoes da fila
        quando o objeto e chamado dentro de um print() 
        ou dentro de um str(). 
        """

        # cria uma nova fila auxiliar
        auxfila = FilaEspecial()
        
        # retira os elementos da fila antiga e preenche a auxiliar
        for i in range( self.size ):
            auxfila.enqueue( self.dequeue() )
            
        # cria uma string com os elementos da fila auxiliar e
        # enquanto isso, preenche novamente a fila original
        strfila = '['
        for i in range( auxfila.size ):
            
            base = auxfila.dequeue()
            
            # preenche a fila original
            self.enqueue(base)
            
            # guarda o base em uma string
            strfila += ' ' + str(base)
            
        strfila += ' ]'
        
        return strfila
        
if __name__ == "__main__":
    
    # testando a fila
    fila = FilaEspecial(10)
    
    fila.enqueue(5)
    print(fila)

    fila.push(99)
    print(fila)

    valor = fila.pop()
    print(fila)
    
    fila.enqueue(3)
    print(fila)
    
    print( 'Size: ', fila.getSize() )
    
    valor = fila.dequeue()
    print(fila)
    
    print( 'Vazia?: ', fila.isEmpty() )
    
    valor = fila.dequeue()
    print(fila)
    
    print( 'Vazia?: ', fila.isEmpty() )
    
    valor = fila.dequeue()
    print(fila)
    
    fila.enqueue(2)
    print(fila)
    
    fila.enqueue(14)
    print(fila)
    
    fila.push(99)
    print(fila)
    
    fila.clear()
    print( 'Vazia?: ', fila.isEmpty() )
    
    
     





##########################################################################

# %% [markdown]
# ---
# ## Exercício 6
#
# Crie uma função recursiva chamada **ComparaArvores** que receba duas árvores e compare se são iguais.
#
# As árvores são iguais caso elas tenham exatamente a mesma estrutura e os mesmos valores armazenados exatamente nos mesmos nós.

# %%
class Node:
  def __init__(self,data):
    self.data = data
    self.left = None
    self.right = None

  def comparaArvore(arvoreX,arvoreY):
    # Caso padrão 1: se as árvores estiverem vazias:
    if arvoreX is None and arvoreY is None:
      return True

    # Caso padrão 2: se uma das árvores estiver vazia:
    if arvoreX is None or arvoreY is None:
      return False

    # Caso padrão 3: se as árvores forem diferentes:
    if arvoreX.data != arvoreY.data:
      return False
    
    # Compara as subárvores esquerdas e direitas recursivamente.
    return (Node.comparaArvore(arvoreX.left,arvoreY.left) and Node.comparaArvore(arvoreX.right,arvoreY.right))

# -----------------------------------------------------------------------------
# 1º Verificação
print("|--------------------------------|")
print("|-------| 1º Verificação |-------|")
arvoreX = Node(1)
arvoreX.left = Node(2)
arvoreX.right = Node(3)

arvoreY = Node(1)
arvoreY.left = Node(2)
arvoreY.right = Node(3)

print("Conclusão de verificação: ",Node.comparaArvore(arvoreX,arvoreY)) # Retorno: verdadeiro
# -----------------------------------------------------------------------------
# 2º Verificação
print("|--------------------------------|")
print("|-------| 2º Verificação |-------|")

arvoreX = Node(1)
arvoreX.left = Node(2)
arvoreX.left = Node(4)
arvoreX.right = Node(3)
arvoreX.right = Node(5)

arvoreY = Node(1)
arvoreY.left = Node(2)
arvoreY.left = Node(4)
arvoreY.right = Node(3)
arvoreY.right = Node(5)

print("Conclusão de verificação: ",Node.comparaArvore(arvoreX,arvoreY)) # Retorno: verdadeiro
print("|--------------------------------|")
# -----------------------------------------------------------------------------
# 3º Verificação
print("|-------| 3º Verificação |-------|")
arvoreX = Node(0)

arvoreY = Node(0)

print("Conclusão de verificação: ",Node.comparaArvore(arvoreX,arvoreY)) # Retorno: verdadeiro
print("|--------------------------------|")
# -----------------------------------------------------------------------------
# 4º Verificação
print("|-------| 4º Verificação |-------|")
arvoreX = Node(2)
arvoreX.left = Node(4)
arvoreX.right = Node(6)

arvoreY = Node(1)
arvoreY.left = Node(3)
arvoreY.right = Node(5)

print("Conclusão de verificação: ",Node.comparaArvore(arvoreX,arvoreY)) # Retorno: falso
print("|--------------------------------|")
# -----------------------------------------------------------------------------
# 5º Verificação
print("|-------| 5º Verificação |-------|")
arvoreX = Node(1)
arvoreX.left = Node(2)
arvoreX.left = Node(4)
arvoreX.right = Node(3)
arvoreX.right = Node(5)

arvoreY = Node(1)
arvoreY.left = Node(3)
arvoreY.right = Node(5)

print("Conclusão de verificação: ",Node.comparaArvore(arvoreX,arvoreY)) # Retorno: falso
print("|--------------------------------|")
# -----------------------------------------------------------------------------

# %% [markdown]
# ---
# ## Exercício 7
#
# Modifique a árvore binária de busca ensinada nesta disciplina e dê o nome de **TreePath**. Acrescente nessa árvore um método chamado **caminhos**. Esse método deve preencher um objeto da lista duplamente ligada fornecida junto com este notebook com a soma do valores dos nós que estão no caminho de cada um dos nós folhas até a raiz da árvore. Por exemplo, considere a árvore apresentada abaixo:
#
# ```
#             ___________61___________
#            |                        |
#        ____34_____              ____67____
#       |           |            |          |
#       19__        50__      __66        __94__
#           |           |    |           |      |
#          20           55   64          70     95
# ```
#
# Se a árvore acima fosse apresentada como entrada, o método **caminhos** deveria retornar uma lista duplamente ligada com os seguintes valores: [134, 200, 258, 292, 317], que é formada pelas seguites somas: [61+34+19+20, 61+34+50+55, 61+67+66+64, 61+67+94+70, 61+67+94+95].

# %%
# Define a classe Node que representa um nó em uma árvore binária.
class Node:
  def __init__(self,data):
    self.data = data
    self.right = None
    self.left = None

# Define a classe TreePath que representa uma árvore binária
class TreePath:
  def __init__(self):
    self.root = None
  
  def insert(self,data,node=None):
    # Insere um novo nó na árvore com o valor do elemento desejado.
    # Se a raiz não existe, cria um novo nó como raiz.
    # Caso contrário, percorre a árvore para encontrar a posição correta para inserir o elemento desejado.
    if self.root is None:
      self.root = Node(data)
    else:
      if node is None:
        node = self.root
      if data < node.data:
        if node.left is None:
          node.left = Node(data)
        else:
          self.insert(data,node.left)
      else:
        if node.right is None:
          node.right = Node(data)
        else:
          self.insert(data,node.right)

  def strInorder(self,node=-1,info=''):
    # Retorna uma representação em ordem dos elementos da árvore.
    # Se a raiz não existe, retorna uma string vazia.
    # Caso contrário, percorre a árvore em ordem recursivamente.
    if self.root is None:
      return ''
    else:
      if node == -1:
        node = self.root
      if node.data is not None:
        if node.left is not None:
          info += self.strInorder(node.left)
        info += '' + str(node.data)
        if node.right is not None:
          info += self.strInorder(node.right)
        return info
      else:
        return info
      
  def strPreorder(self,node=-1,info=''):
    # Retorna uma representação em pré-ordem dos elementos da árvore.
    # Se a raiz não existe, retorna uma string vazia.
    # Caso contrário, perecorre a árvore em pré-ordem recursivamente. 
    if self.root is None:
      return ''
    else:
      if node == -1:
        node = self.root
      if node.data is not None:
        info += '' + str(node.data)
        if node.left is not None:
          info += self.strPreorder(node.left)
        if node.right is not None:
          info += self.strPreorder(node.right)
        return info
      else:
        return info

  def strPostorder(self,node=-1,info=''):
    # Retorna uma representação em pós-ordem dos elementos da árvore.
    # Se a raiz não existe, retorna uma string vazia.
    # Caso contrário, perecorre a árvore em pós-ordem recursivamente. 
    if self.root is None:
      return ''
    else:
      if node == -1:
        node = self.root
      if node.data is not None:
        if node.left is not None:
          info += self.strPostorder(node.left)
        if node.right is not None:
          info += self.strPostorder(node.right)
        info +='' + str(node.data)
        return info
      else:
        return info
  
  def search(self,valor,anode=-1):
    # Realiza uma busca pelo elemento desejado da árvore.
    # Se o nó especificado por nulo (-1), inicia a busca pela raiz da árvore.
    if anode == -1:
      anode = self.root
    # Se o nó atual for nulo (None), retorna falso, indicando que o elemento não foi encontrado.
    if anode is None:
      return False
    # Se o nó atual for igual ao elemento desejado, retorna verdadeiro, indicando que o elemento foi encontrado.
    elif valor == anode.data:
      return True
    # Se o elemento desejado for menor que o nó atual, faz uma busca recursiva na subárvore esquerda.
    elif valor < anode.data:
      return self.search(valor,anode.left)
    # Caso contrário, faz uma busca recursiva na subárvore direita.
    else:
      return self.search(valor,anode.right)

  def path(self,node=None,sum=0,path_list=None):
    # Retorna uma lsita contendo as somas de todos os caminhos da raiz até as folhas das árvores
    # Se o nó especificado por nulo (None), inicia o caminho pela raiz da árvore.
    if node is None:
      node = self.root
    # Se a lsita de caminhos não for especificada, cria uma nova lista vazia.
    if path_list is None:
      path_list = []
    # Se o nó atual não for nulo (None), incrementa a soma com o valor do nó atual.
    if node is not None:
      sum += node.data
      # Se o nó atual for uma folha, adiciona a soma à lista de caminhos
      if node.left is None and node.right is None:
        path_list.append(sum)
      # Faz chamadas recursivas para os nós filhos, se existirem.
      if node.left:
        self.path(node.left,sum,path_list)
      if node.right:
        self.path(node.right,sum,path_list)
    # Retorna a lista de caminhos atualizada.
    return path_list

# Cria uma nova instância da classe TreePath.
tree = TreePath()

# Insere os valores na árvore.
tree.insert(61)
tree.insert(34)
tree.insert(67)
tree.insert(19)
tree.insert(50)
tree.insert(66)
tree.insert(94)
tree.insert(20)
tree.insert(55)
tree.insert(64)
tree.insert(70)
tree.insert(95)

# Calcula a lista de caminhos na árvore e armazena em path_list.
path_list = tree.path()

print(path_list) # [134, 200, 258, 292, 317]

# %% [markdown]
# # Exercício 8 - Extra (Desafio) - apresentado após o conteúdo de grafos!
